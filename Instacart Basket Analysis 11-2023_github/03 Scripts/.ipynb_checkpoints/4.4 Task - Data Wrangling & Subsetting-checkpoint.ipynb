# %% [markdown]
# # 4.4 Data Wrangling & Subsetting

# %% [markdown]
# ### Contents List
#
# #### Practice Work:
# #### 1. Importing libraries
# #### 2. Importing Data
# #### 3. Dropping columns
# #### 4. Renaming columns
# #### 5. Changing data types
# #### 6. Transposing Data
# #### 7. Data Dictionaries
# #### 8. Subsetting
# #### 9. Exporting Dataframes
# #### Task:
# #### Question 2
# #### Question 3
# #### Question 4
# #### Question 5
# #### Question 6
# #### Question 7
# #### Question 8
# #### Question 9
# #### Question 10
# #### Question 11
# #### Question 12
# #### Question 13
# #### Question 14

# %% [markdown]
# #### Practice Work:

# %% [markdown]
# #### 1. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #### 2. Importing data

# %%
# declare path as variable
path = r'/Users/dekstrom/Documents/Career Foundry/Instacart Basket Analysis 11-2023'

# %%
# import orders.csv as dataframe
df_ords = pd.read_csv(os.path.join(path,'02 Data','Original Data','orders.csv'), index_col = False)

# %%
# import products.csv as dataframe
df_prods = pd.read_csv(os.path.join(path,'02 Data','Original Data','products.csv'), index_col = False)

# %% [markdown]
# #### 3. Dropping columns

# %%
df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %% [markdown]
# #### 4. Renaming columns

# %%
df_ords.rename(columns = {'order_dow':'orders_day_of_week'},inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %% [markdown]
# #### 5. Changing data types

# %%
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### 6. Transposing data

# %%
# importing data set departments.csv
df_dep = pd.read_csv(os.path.join(path,'02 Data','Original Data','departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T

# %%
df_dep_t.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep_t.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new.head()
# Out:
#          0
# 1   frozen
# 2    other
# 3   bakery
# 4  produce
# 5  alcohol

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# #### 7. Data dictionaries

# %%
#creates data dictionary
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %% [markdown]
# #### 8. Subsetting

# %%
# creates new data frame with only snacks
df_snacks = df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_snacks_2 = df_prods.loc[df_prods['department_id']==19]

# %%
df_snacks_2.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([19])]

# %% [markdown]
# #### 9. Exporting dataframes

# %%
# syntax for exporting:
# df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %% [markdown]
# #### Task:

# %% [markdown]
# #### Question 2
#
# Find another identifier variable in the df_ords dataframe that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.

# %%
# show df_ords to identify non-numeric variable
df_ords.head()
# Out:
#   order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329        1             1                   2                  8
# 1  2398795        1             2                   3                  7
# 2   473747        1             3                   3                 12
# 3  2254736        1             4                   4                  7
# 4   431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# change data type of user_id tp string since it's an ID and doesn't represent a useable numerical value
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
# confirm new data type of user_id is object (string)
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# #### Question 3
#
# Look for a variable in your df_ords dataframe with an unintuitive name and change its name without overwriting the dataframe.

# %%
# show column names to identify unintuitive name
df_ords.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
# change name of column without overwriting existing column name
df_ords.rename(columns = {'order_number':'number_of_orders'},inplace = False)
# Out:
#         order_id user_id  number_of_orders  orders_day_of_week  \
# 0        2539329       1                 1                   2
# 1        2398795       1                 2                   3
# 2         473747       1                 3                   3
# 3        2254736       1                 4                   4
# 4         431534       1                 5                   4
# ...          ...     ...               ...                 ...
# 3421078  2266710  206209                10                   5
# 3421079  1854736  206209                11                   4
# 3421080   626363  206209                12                   1
# 3421081  2977660  206209                13                   1
# 3421082   272231  206209                14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
# show that df_ords has not been overwritten
df_ords.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# save renamed data frame as new data frame
df_ords_renamed = df_ords.rename(columns = {'order_number':'number_of_orders'},inplace = False)

# %%
# show new renamed dataframe
df_ords_renamed.head()
# Out:
#   order_id user_id  number_of_orders  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1                 1                   2                  8
# 1  2398795       1                 2                   3                  7
# 2   473747       1                 3                   3                 12
# 3  2254736       1                 4                   4                  7
# 4   431534       1                 5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# #### Question 4
#
# Your client wants to know what the busiest hour is for placing orders. Find the frequency of the corresponding variable and share your findings.

# %%
# show value count for order_hour_of_day
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# ##### Findings
#
# The busiest hour (in terms of orders placed) is 10AM. Peak busy hours are from about 9AM to 3PM. 2AM to 5AM is the least busy time for placing orders.

# %% [markdown]
# #### Question 5
#
# Determine the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.

# %%
# import departments.csv data set
df_dept = pd.read_csv(os.path.join(path,'02 Data','Original Data','departments.csv'), index_col = False)

# %%
# show df_dept
df_dept.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# transpose df_dept
df_dept_t = df_dept.T

# %%
# show df_dept_t
df_dept_t.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
# reset index of df_dept_t
df_dept_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
df_dept_t.head()
# Out:
#                         0
# department_id  department
# 1                  frozen
# 2                   other
# 3                  bakery
# 4                 produce

# %%
# create variable for header row
dept_new_header = df_dept_t.iloc[0]

# %%
# remove row 0
df_dept_t_new = df_dept_t[1:]

# %%
# add header to df_dept_t_new
df_dept_t_new.columns = dept_new_header

# %%
# show df_dept_t_new
df_dept_t_new.head()
# Out:
# department_id department
# 1                 frozen
# 2                  other
# 3                 bakery
# 4                produce
# 5                alcohol

# %%
# create data dictionary for df_dept_t_new
data_dict_dept = df_dept_t_new.to_dict('index')

# %%
# show data_dict_dept
data_dict_dept
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# find meaning of Department ID = 4
print(data_dict_dept.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# ##### Findings
#
# The meaning of a Department ID of 4 is the **produce** department.

# %% [markdown]
# #### Question 6
#
# The sales team in your client’s organization wants to know more about breakfast item sales. Create a subset containing only the required information.

# %%
# find Department ID for breakfast items
df_dept_t_new[df_dept_t_new['department']=='breakfast']
# Out:
# department_id department
# 14             breakfast

# %%
# create subset of df_prods for breakfast items
df_breakfast = df_prods[df_prods['department_id']==14]

# %%
# reset index for df_breakfast
df_breakfast = df_breakfast.reset_index(drop=True)

# %%
# show df_breakfast
df_breakfast
# Out:
#       product_id                                       product_name  aisle_id  \
# 0             28                                  Wheat Chex Cereal       121
# 1             34                                                NaN       121
# 2             68                            Pancake Mix, Buttermilk       130
# 3             90                                       Smorz Cereal       121
# 4            211   Gluten Free Organic Cereal Coconut Maple Vanilla       130
# ...          ...                                                ...       ...
# 1111       49326                            Cereal Variety Fun Pack       121
# 1112       49391            Light and Fluffy Buttermilk Pancake Mix       130
# 1113       49543                          Chocolate Cheerios Cereal       121
# 1114       49633               Shake 'N Pour Buttermilk Pancake Mix       130
# 1115       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...        57
#
#       department_id  prices
# ...

# %% [markdown]
# #### Question 7
#
# They’d also like to see details about products that customers might use to throw dinner parties. Your task is to find all observations from the entire dataframe that include items from the following departments: alcohol, deli, beverages, and meat/seafood. You’ll need to present this subset to your client.

# %%
# create subset of df_dept for dinner-related departments and reset index
df_din_dept = df_dept_t_new[df_dept_t_new['department'].isin(['alcohol','deli','beverages','meat seafood'])].reset_index()

# %%
# rename columns
df_din_dept.columns = ['department_id','department']

# %%
# get list of department ids for dinner party departments
din_dept_list = df_din_dept['department_id'].tolist()

# %%
# convert list to ints
din_dept_list = [int(x) for x in din_dept_list]

# %%
# subset of df_prods that only includes dinner party observations
df_dinner = df_prods[df_prods['department_id'].isin(din_dept_list)]

# %%
# reset index for df_dinner
df_dinner = df_dinner.reset_index(drop=True)

# %%
# show df_dinner
df_dinner
# Out:
#       product_id                                    product_name  aisle_id  \
# 0              3            Robust Golden Unsweetened Oolong Tea        94
# 1              7                  Pure Coconut Water With Orange        98
# 2             10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 3             11                               Peach Mango Juice        31
# 4             17                               Rendered Duck Fat        35
# ...          ...                                             ...       ...
# 7645       49672                          Cafe Mocha K-Cup Packs        26
# 7646       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 7647       49676                          Ultra Red Energy Drink        64
# 7648       49682                              California Limeade        98
# 7649       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#       department_id  prices
# 0                 7     4.5
# ...

# %% [markdown]
# #### Question 8
#
# It’s important that you keep track of total counts in your dataframes. How many rows does the last dataframe you created have?

# %%
# return number of rows and columns of df_dinner
df_dinner.shape
# Out:
# (7650, 5)

# %% [markdown]
# ##### Findings
#
# The last dataframe I created has **7,650** rows.

# %% [markdown]
# #### Question 9
#
# Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the customer with a "user_id" of “1.” Extract all the information you can about this user.

# %% [markdown]
# #### Question 10
#
# You also need to provide some details about this user’s behavior. What basic stats can you provide based on the information you have?

# %% [markdown]
# ###### The following code answers both questions 9 & 10.

# %%
# create df for user_id = 1
df_ords_user1 = df_ords[df_ords['user_id']=='1']

# %%
# show df_ords_user1
df_ords_user1
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
# 5   3367565       1             6                   2                  7
# 6    550135       1             7                   1                  9
# 7   3108588       1             8                   1                 14
# 8   2295261       1             9                   1                 16
# 9   2550362       1            10                   4                  8
# 10  1187899       1            11                   4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# ...

# %%
# show df_ords_user1 head
df_ords_user1.head(5)
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# show df_ords_user1 tail
df_ords_user1.tail(5)
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 6    550135       1             7                   1                  9
# 7   3108588       1             8                   1                 14
# 8   2295261       1             9                   1                 16
# 9   2550362       1            10                   4                  8
# 10  1187899       1            11                   4                  8
#
#     days_since_prior_order
# 6                     20.0
# 7                     14.0
# 8                      0.0
# 9                     30.0
# 10                    14.0

# %%
# shape of df_ords_user1
df_ords_user1.shape
# Out:
# (11, 6)

# %%
# info for df_ords_user1
df_ords_user1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                11 non-null     object
#  1   user_id                 11 non-null     object
#  2   order_number            11 non-null     int64
#  3   orders_day_of_week      11 non-null     int64
#  4   order_hour_of_day       11 non-null     int64
#  5   days_since_prior_order  10 non-null     float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 616.0+ bytes

# %%
# describe df_ords_user1
df_ords_user1.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count     11.000000           11.000000          11.000000
# mean       6.000000            2.636364          10.090909
# std        3.316625            1.286291           3.477198
# min        1.000000            1.000000           7.000000
# 25%        3.500000            1.500000           7.500000
# 50%        6.000000            3.000000           8.000000
# 75%        8.500000            4.000000          13.000000
# max       11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# show df_ords_user1 data types
df_ords_user1.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number                int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# show df_ords_user1 columns
df_ords_user1.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %% [markdown]
# ##### Findings
#
# User_id 1

# %% [markdown]
# #### Question 12
#
# Export your df_ords dataframe as “orders_wrangled.csv” in your “Prepared Data” folder.

# %%
# explort df_ords as orders_wrangled.csv in Prepared Data folder
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled_1.csv'), index=False)

# %% [markdown]
# #### Question 13
#
# Export the df_dep_t_new dataframe as “departments_wrangled.csv” in your “Prepared Data” folder so that you have a “.csv” file of your departments data in the correct format.

# %%
# explort df_dep as orders_wrangled.csv in Prepared Data folder
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv'))

# %% [markdown]
# #### Question 14
#
# Save your Jupyter notebook and submit it here for your tutor to review.

# %%
df_ords.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %%
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
df_dep_t_new.head()
# Out:
# department_id department
# 1                 frozen
# 2                  other
# 3                 bakery
# 4                produce
# 5                alcohol
